# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
newapplication_df = application_df.drop(columns = ['EIN', 'NAME'])
newapplication_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
uniquevaluecounts = newapplication_df.nunique()
uniquevaluecounts
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
valuecnts = newapplication_df['APPLICATION_TYPE'].value_counts()
valuecnts_df = pd.DataFrame(valuecnts)
valuecnts_df.dtypes
to_replace = []
valcnts_not_reqd= newapplication_df['APPLICATION_TYPE'].value_counts() < 500
valcnts_not_reqd[8:]
valuecnts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

application_types_to_replace = ['T9','T12', 'T13', 'T14', 'T25', 'T29', 'T17','T2', 'T15']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
new_classificationcnts = newapplication_df['CLASSIFICATION'].value_counts()
classificationcnts = pd.DataFrame(data=new_classificationcnts)
classificationcnts.reset_index()
newclassificationcnts = classificationcnts.loc[classificationcnts['CLASSIFICATION']>1, :]
newclassificationcnts
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# C7000             777
# C1700             287
# C4000             194
# C5000             116
# C1270             114
# C2700             104
# C2800              95
# C7100              75
# C1300              58
# C1280              50
# C1230              36
# C1400              34
# C7200              32
# C2300              32
# C1240              30
# C8000              20
# C7120              18
# C1500              16
# C1800              15
# C6000              15
# C1250              14
# C8200              11
# C1238              10
# C1278              10
# C1235               9
# C1237               9
# C7210               7
# C2400               6
# C1720               6
# C4100               6
# C1257               5
# C1600               5
# C1260               3
# C2710               3
# C0                  3
# C3200               2
# C1234               2
# C1246               2
# C1267               2
# C1256               2

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
newclassificationcnts
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# C7000             777
# C1700             287
# C4000             194
# C5000             116
# C1270             114
# C2700             104
# C2800              95
# C7100              75
# C1300              58
# C1280              50
# C1230              36
# C1400              34
# C7200              32
# C2300              32
# C1240              30
# C8000              20
# C7120              18
# C1500              16
# C1800              15
# C6000              15
# C1250              14
# C8200              11
# C1238              10
# C1278              10
# C1235               9
# C1237               9
# C7210               7
# C2400               6
# C1720               6
# C4100               6
# C1257               5
# C1600               5
# C1260               3
# C2710               3
# C0                  3
# C3200               2
# C1234               2
# C1246               2
# C1267               2
# C1256               2

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = []
other_classifications=classificationcnts.loc[classificationcnts['CLASSIFICATION']<1000, 'CLASSIFICATION']
OC_df = pd.DataFrame(other_classifications)
classifications_to_replace.append(OC_df.index)
classifications_to_replace

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categoryto_numeric_df = pd.get_dummies(newapplication_df)
categoryto_numeric_df.shape
# Out:
# (34299, 117)

# %%
# Split our preprocessed data into our features and target arrays
X = categoryto_numeric_df.drop(columns = 'STATUS')
y = categoryto_numeric_df['STATUS']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify =y)
X_train.columns[:40]
first40_X_train = X_train[['ASK_AMT', 'IS_SUCCESSFUL', 'APPLICATION_TYPE_T10',
       'APPLICATION_TYPE_T12', 'APPLICATION_TYPE_T13', 'APPLICATION_TYPE_T14',
       'APPLICATION_TYPE_T15', 'APPLICATION_TYPE_T17', 'APPLICATION_TYPE_T19',
       'APPLICATION_TYPE_T2', 'APPLICATION_TYPE_T25', 'APPLICATION_TYPE_T29',
       'APPLICATION_TYPE_T3', 'APPLICATION_TYPE_T4', 'APPLICATION_TYPE_T5',
       'APPLICATION_TYPE_T6', 'APPLICATION_TYPE_T7', 'APPLICATION_TYPE_T8',
       'APPLICATION_TYPE_T9', 'AFFILIATION_CompanySponsored',
       'AFFILIATION_Family/Parent', 'AFFILIATION_Independent',
       'AFFILIATION_National', 'AFFILIATION_Other', 'AFFILIATION_Regional',
       'CLASSIFICATION_C0', 'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200',
       'CLASSIFICATION_C1230', 'CLASSIFICATION_C1234', 'CLASSIFICATION_C1235',
       'CLASSIFICATION_C1236', 'CLASSIFICATION_C1237', 'CLASSIFICATION_C1238',
       'CLASSIFICATION_C1240', 'CLASSIFICATION_C1245', 'CLASSIFICATION_C1246',
       'CLASSIFICATION_C1248', 'CLASSIFICATION_C1250', 'CLASSIFICATION_C1256']]
first40_X_train
X_test.columns[:40]
X_test_first40 = X_test[['ASK_AMT', 'IS_SUCCESSFUL', 'APPLICATION_TYPE_T10',
       'APPLICATION_TYPE_T12', 'APPLICATION_TYPE_T13', 'APPLICATION_TYPE_T14',
       'APPLICATION_TYPE_T15', 'APPLICATION_TYPE_T17', 'APPLICATION_TYPE_T19',
       'APPLICATION_TYPE_T2', 'APPLICATION_TYPE_T25', 'APPLICATION_TYPE_T29',
       'APPLICATION_TYPE_T3', 'APPLICATION_TYPE_T4', 'APPLICATION_TYPE_T5',
       'APPLICATION_TYPE_T6', 'APPLICATION_TYPE_T7', 'APPLICATION_TYPE_T8',
       'APPLICATION_TYPE_T9', 'AFFILIATION_CompanySponsored',
       'AFFILIATION_Family/Parent', 'AFFILIATION_Independent',
       'AFFILIATION_National', 'AFFILIATION_Other', 'AFFILIATION_Regional',
       'CLASSIFICATION_C0', 'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200',
       'CLASSIFICATION_C1230', 'CLASSIFICATION_C1234', 'CLASSIFICATION_C1235',
       'CLASSIFICATION_C1236', 'CLASSIFICATION_C1237', 'CLASSIFICATION_C1238',
       'CLASSIFICATION_C1240', 'CLASSIFICATION_C1245', 'CLASSIFICATION_C1246',
       'CLASSIFICATION_C1248', 'CLASSIFICATION_C1250', 'CLASSIFICATION_C1256']]
X_test_first40
y_test
# Out:
# 26554    1
# 4919     1
# 7337     1
# 8855     1
# 33414    1
#         ..
# 15581    1
# 30389    1
# 7787     1
# 5966     1
# 23763    1
# Name: STATUS, Length: 8575, dtype: int64

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(first40_X_train)

# Scale the data
X_train_scaled = X_scaler.transform(first40_X_train)
X_test_scaled = X_scaler.transform(X_test_first40)
print(len(X_train_scaled))
print(y_train)
X_train_scaled
# Out:
# 25724
# 28050    1
# 29468    1
# 7064     1
# 14303    1
# 17339    1
#         ..
# 1068     1
# 5940     1
# 14586    1
# 31609    1
# 19089    1
# Name: STATUS, Length: 25724, dtype: int64
# array([[-0.03221076,  0.93830131, -0.12615722, ..., -0.00623504,
#         -0.01972038, -0.00881785],
#        [-0.03080054, -1.06575573, -0.12615722, ..., -0.00623504,
#         -0.01972038, -0.00881785],
#        [-0.03221076,  0.93830131, -0.12615722, ..., -0.00623504,
#         -0.01972038, -0.00881785],
#        ...,
#        [-0.03221076,  0.93830131, -0.12615722, ..., -0.00623504,
#         -0.01972038, -0.00881785],
#        [-0.03221076, -1.06575573, -0.12615722, ..., -0.00623504,
#         -0.01972038, -0.00881785],
#        [-0.02811722,  0.93830131, -0.12615722, ..., -0.00623504,
#         -0.01972038, -0.00881785]])

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()
# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=40))
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=30))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 80)                3280
#
#  dense_49 (Dense)            (None, 30)                2430
#
#  dense_50 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 5741 (22.43 KB)
# Trainable params: 5741 (22.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy",optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
train_model = nn.fit(X_train_scaled, y_train, epochs=100, batch_size=10)
train_model
# Out:
# Epoch 1/100
# 2573/2573 [==============================] - 4s 1ms/step - loss: 0.0094 - accuracy: 0.9984
# Epoch 2/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 3/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 4/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 5/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 6/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 7/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 8/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 9/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 10/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 11/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 12/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 13/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 14/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 15/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 16/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 17/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 18/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 19/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 20/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 21/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 22/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 23/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 24/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 25/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 26/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 27/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 28/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 29/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 30/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0021 - accuracy: 0.9998
# Epoch 31/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 32/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 33/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 34/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 35/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 36/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 37/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 38/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 39/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 40/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 41/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 42/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 43/100
# 2573/2573 [==============================] - 4s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 44/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 45/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0019 - accuracy: 0.9998
# Epoch 46/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 47/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 48/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 49/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 50/100
# 2573/2573 [==============================] - 4s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 51/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 52/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 53/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 54/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 55/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0019 - accuracy: 0.9998
# Epoch 56/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 57/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 58/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 59/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 60/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 61/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 62/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 63/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 64/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 65/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 66/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 67/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 68/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 69/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 70/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 71/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 72/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 73/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 74/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0019 - accuracy: 0.9998
# Epoch 75/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 76/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 77/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0022 - accuracy: 0.9998
# Epoch 78/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 79/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 80/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 81/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0022 - accuracy: 0.9998
# Epoch 82/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 83/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 84/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 85/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 86/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 87/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 88/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 89/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 90/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 91/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 92/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 93/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 94/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 95/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 96/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 97/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 98/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 99/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 100/100
# 2573/2573 [==============================] - 3s 1ms/step - loss: 0.0018 - accuracy: 0.9998

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.0013 - accuracy: 0.9999 - 322ms/epoch - 1ms/step
# Loss: 0.0013347549829632044, Accuracy: 0.9998833537101746

# %%
# Export our model to HDF5 file
nn.save('model.h5')
nn.save('my_model.keras')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
